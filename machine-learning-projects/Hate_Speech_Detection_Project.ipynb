# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Siam\Downloads\Hate_Speech_Detection_Project.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Siam/Downloads/Hate_Speech_Detection_Project.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Siam/Downloads/Hate_Speech_Detection_Project.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/Siam/Downloads/Hate_Speech_Detection_Project.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.feature_extraction.text import CountVectorizer
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas numpy sklearn

# %%
import nltk
nltk.download('stopwords')
import re
from nltk.corpus import stopwords
stopword=set(stopwords.words('english'))
stemmer = nltk.SnowballStemmer('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data=pd.read_csv('/content/Ai Project  - Form Responses 1 (7).csv')

print(data.head())
# Out:
#             Timestamp          Email Address  count  hate_speech  \
# 0  11/24/2023 4:09:19    mir10siam@gmail.com      2            3
# 1  11/24/2023 4:53:45   siyamraw10@gmail.com      2            3
# 2  11/24/2023 4:55:20  mir15-4438@diu.edu.bd      1            3
#
#    offensive_speech  neither  class  \
# 0                 2        0      2
# 1                 2        0      0
# 2                 0        0      0
#
#                                              tweet
# 0                                     You are ugly
# 1  You are too bad and I don't like your attitude
# 2                                         Hate you

# %%
data["labels"]=data["class"].map({0:"Hate Speech", 1:"Offensive Speech", 2:"No hate and offensive speech"})

# %%
data=data[["tweet","labels"]]

# %%
data.head()
# Out:
#                                              tweet  \
# 0                                     You are ugly
# 1  You are too bad and I don't like your attitude
# 2                                         Hate you
#
#                          labels
# 0  No hate and offensive speech
# 1                   Hate Speech
# 2                   Hate Speech
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('tweet').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('labels').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['labels'].value_counts()
#     for x_label, grp in _df_8.groupby('tweet')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('tweet')
# _ = plt.ylabel('labels')

# %%
import re

# %%
def clean(text):
  text = str(text).lower()
  text = re.sub('[.?]',' ',text)
  text = re.sub('https?://\S+|www.\S+',' ', text)
  text = re.sub('<.*?>','',text)
  text = re.sub(r'[^\w\s]',' ',text)
  text = re.sub('\n','',text)
  text = re.sub('\w\d\w', ' ' , text)
  text = [word for word in text.split(' ') if word in stopword]
  text = " ".join(text)
  text = [stemmer. stem(word) for word in text. split(' ')]
  text = " ".join(text)
  return text
data["tweet"] = data["tweet"].apply(clean)

# %%
stop_words = set(stopwords.words("english"))

# %%
x=np.array(data["tweet"])
y=np.array(data["labels"])

# %%
data.head
# Out:
# <bound method NDFrame.head of                           tweet                        labels
# 0                       you are  No hate and offensive speech
# 1  you are too and i don t your                   Hate Speech
# 2                           you                   Hate Speech>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
cv = CountVectorizer()

# %%
X = cv.fit_transform(x)
print(X)
# Out:
#   (0, 4)	1
#   (0, 1)	1
#   (1, 4)	1
#   (1, 1)	1
#   (1, 3)	1
#   (1, 0)	1
#   (1, 2)	1
#   (1, 5)	1
#   (2, 4)	1

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.0

# %%
i="You are too bad and I dont like your attitude"
i = cv.transform([i]).toarray()
print(model.predict((i)))
# Out:
# ['Hate Speech']
